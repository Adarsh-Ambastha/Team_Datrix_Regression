# %% [markdown]
# # Data Visualization and Preprocessing

# %% [markdown]
# ###
#
# **## Importing all the tools usefull for visualization and importing data**

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import gdown
import plotly.express as px
import seaborn as sns

# %% [markdown]
# ### **Downloading the scrapped file from drive and saving it in local directory :**

# %%
# Google Drive file ID

file_id = "1zF3fYQbAUDE0Jx3lvBHC8GjaK8i9wrno"
# Destination path to save the file
output = r"A:\DAIICT_sem1\Used_car_Price_prediction\Prediction\cars24data.csv"
# Download the file from Google Drive
gdown.download(f"https://drive.google.com/uc?id={file_id}", output, quiet=False)
# Out:
# Downloading...
# From: https://drive.google.com/uc?id=1zF3fYQbAUDE0Jx3lvBHC8GjaK8i9wrno
# To: A:\DAIICT_sem1\Used_car_Price_prediction\Prediction\cars24data.csv
# 100%|██████████| 113k/113k [00:00<00:00, 865kB/s]
# 'A:\\DAIICT_sem1\\Used_car_Price_prediction\\Prediction\\cars24data.csv'

# %% [markdown]
# ### **Using pandas to read the csv file :**

# %%
path=r'A:\DAIICT_sem1\Used_car_Price_prediction\Prediction\cars24data.csv' 
cars_24_data_frame=pd.read_csv(path)

# %% [markdown]
# ### **Displaying all the features of cars_24_data_frame :**

# %%
cars_24_data_frame.columns
# Out:
# Index(['Model Name', 'Price', 'Manufacturing_year', 'Engine capacity',
#        'Spare key', 'Transmission', 'KM driven', 'Ownership', 'Fuel type',
#        'Imperfections', 'Repainted Parts'],
#       dtype='object')

# %%
# Displaying the top 5 tuples inside the dat frame
cars_24_data_frame.head()
# Out:
#                             Model Name    Price  Manufacturing_year  \
# 0                2017 Maruti Swift VXI   561000                2017
# 1  2016 Maruti Baleno DELTA PETROL 1.2   498000                2016
# 2                2020 Maruti Swift VXI   577000                2020
# 3       2022 Maruti Ertiga VXI AT SHVS  1084000                2022
# 4                2019 Maruti Dzire VXI   603000                2019
#
#    Engine capacity Spare key Transmission  KM driven  Ownership Fuel type  \
# 0             1197        No       Manual      25847          2    Petrol
# 1             1197       Yes       Manual      55511          2    Petrol
# 2             1197        No       Manual      47110          1    Petrol
# 3             1462       Yes    Automatic      35378          1    Petrol
# 4             1197       Yes       Manual      91856          1    Petrol
#
#    Imperfections  Repainted Parts
# 0              6                2
# 1             12                1
# ...

# %%
# Displaying the bottom 5 tuples inside the dat frame
cars_24_data_frame.tail()
# Out:
#                                Model Name   Price  Manufacturing_year  \
# 1440          2021 Maruti Ertiga VXI SHVS  862000                2021
# 1441                 2015 Maruti Ciaz ZXI  507000                2015
# 1442  2019 Maruti Baleno DELTA PETROL 1.2  554000                2019
# 1443     2017 Maruti Ciaz S 1.4 MT PETROL  557000                2017
# 1444          2012 Maruti Wagon R 1.0 LXI  256000                2012
#
#       Engine capacity Spare key Transmission  KM driven  Ownership Fuel type  \
# 1440             1462        No       Manual      19901          1    Petrol
# 1441             1373        No       Manual      50022          1    Petrol
# 1442             1197       Yes       Manual      58679          1    Petrol
# 1443             1373       Yes       Manual      73948          2    Petrol
# 1444              998        No       Manual      55994          1    Petrol
#
#       Imperfections  Repainted Parts
# 1440              1                0
# ...

# %% [markdown]
# **Number of tuples/ rows in data frame and number of columns in cars24 data frame :**

# %%
print(f'Total number of features in cars24 data frane : {len(cars_24_data_frame.columns)}')
print(f'Total Number of tuples/rows in cars24 data frame : {len(cars_24_data_frame)}')
# Out:
# Total number of features in cars24 data frane : 11
# Total Number of tuples/rows in cars24 data frame : 1445

# %%
# Data type of all the features in data frame of cars24
cars_24_data_frame.columns
# Out:
# Index(['Model Name', 'Price', 'Manufacturing_year', 'Engine capacity',
#        'Spare key', 'Transmission', 'KM driven', 'Ownership', 'Fuel type',
#        'Imperfections', 'Repainted Parts'],
#       dtype='object')

# %% [markdown]
# **Creating a new feature which is car_age from the exisiting feature of manufacturing year :**

# %%
cars_24_data_frame['car_age']=2024-cars_24_data_frame['Manufacturing_year']

# %% [markdown]
# **Getting the data type of all the feature including the new derived feature :**

# %%
cars_24_data_frame.dtypes
# Out:
# Model Name            object
# Price                  int64
# Manufacturing_year     int64
# Engine capacity        int64
# Spare key             object
# Transmission          object
# KM driven              int64
# Ownership              int64
# Fuel type             object
# Imperfections          int64
# Repainted Parts        int64
# car_age                int64
# dtype: object

# %% [markdown]
# ## Getting a small discription of all the attributes :

# %%
cars_24_data_frame.describe()
# Out:
#               Price  Manufacturing_year  Engine capacity      KM driven  \
# count  1.445000e+03         1445.000000      1445.000000    1445.000000
# mean   5.263543e+05         2017.817301      1142.104498   50588.903114
# std    1.963696e+05            2.986554       169.020818   27339.562631
# min    1.390000e+05         2010.000000       796.000000    1207.000000
# 25%    3.900000e+05         2016.000000       998.000000   28803.000000
# 50%    5.010000e+05         2018.000000      1197.000000   47849.000000
# 75%    6.310000e+05         2020.000000      1197.000000   70337.000000
# max    1.599000e+06         2023.000000      1462.000000  124716.000000
#
#          Ownership  Imperfections  Repainted Parts      car_age
# count  1445.000000    1445.000000      1445.000000  1445.000000
# mean      1.285121       9.597232         3.228374     6.182699
# std       0.489877       8.398637         3.364578     2.986554
# ...

# %% [markdown]
# ### Using a histogram for observing number of cars for different ownership :

# %%
fig = px.histogram(cars_24_data_frame, 
                   x=cars_24_data_frame['Ownership'], 
                   marginal='box', 
                   nbins=16, 
                   opacity=0.6,
                   color_discrete_sequence=['red'],
                   title='Number of Owners')
fig.update_layout(bargap=0.5)
fig.show()

# %% [markdown]
# **Overall, the graph shows:**
#
# **The majority of data points have a number of owners between 1 and 2.**
# **There are fewer data points with 3 owners.**
# **There are outliers present in the data, indicated by the individual points outside the whiskers.**
# **This information can be helpful in understanding the ownership patterns within the dataset and identifying any unusual or extreme cases.**

# %% [markdown]
# ### **Using a Histogram for Observing imperfection Class :**

# %%
fig = px.histogram(cars_24_data_frame, 
                   x=cars_24_data_frame['Imperfections'], 
                   marginal='box', 
                   nbins=17, 
                   title='Number of Imperfections')
fig.update_layout(bargap=0.1)
fig.show()

# %% [markdown]
# **Overall, the graph shows:**
#
# **The majority of cars have a relatively low number of imperfections, with most cars having between 0 and 10 imperfections.**
#
# **There are fewer cars with a higher number of imperfections.**
#
# **The distribution is skewed to the right, meaning there are a few cars with a very high number of imperfections (outliers).**

# %% [markdown]
# ```python
#
# ```

# %% [markdown]
# ### **Using a histogram for Observing how many cars had repainted parts in our data set :**

# %%
fig = px.histogram(cars_24_data_frame, 
                   x=cars_24_data_frame['Repainted Parts'], 
                   marginal='box', 
                   nbins=17, 
                   opacity=0.6,
                   color_discrete_sequence=['green'],
                   title='Number of Repainted Parts')
fig.update_layout(bargap=0.1)
fig.show()

# %% [markdown]
# **The graph shows:**
#
# **The majority of cars have a relatively low number of imperfections, with most cars having between 0 and 10 imperfections.**
#
# **There are fewer cars with a higher number of imperfections.**
#
# **The distribution is skewed to the right, meaning there are a few cars with a very high number of imperfections (outliers).**

# %% [markdown]
# ### **Using a histogram for  Observing how many cars are in a particular range  in our data set:**

# %%
fig = px.histogram(cars_24_data_frame, 
                   x=cars_24_data_frame['Price'], 
                   marginal='box', 
                   nbins=17, 
                   opacity=0.6,
                   color_discrete_sequence=['blue'],
                   title='Number of cars in a particular price range')
fig.update_layout(bargap=0.1)
fig.show()

# %% [markdown]
# **The graph shows:**
#
# **The majority of used cars are priced between 0.2M and 0.8M.**
#
# **There are fewer used cars priced above 0.8M, and even fewer below 0.2M.**
#
# **The distribution is skewed to the right, meaning there are a few used cars with very high prices (outliers)**

# %% [markdown]
# ### **Using a Histogram Observing how many km cars have driven :**

# %%
fig = px.histogram(cars_24_data_frame, 
                   x=cars_24_data_frame['KM driven'], 
                   marginal='box', 
                   nbins=17, 
                   opacity=0.5,
                   color_discrete_sequence=['orange'],
                   title='What are the KM driven of used cars ')
fig.update_layout(yaxis_title='Number of cars',bargap=0.2)
fig.show()

# %% [markdown]
# **The graph shows:**
#
# **The majority of used cars have been driven between 20k and 80k kilometers.**
#
# **There are fewer used cars with very low or very high mileage.**
#
# **The distribution is skewed to the right, meaning there are a few used cars with very high mileage (outliers).**

# %% [markdown]
# ### **Using a Scatter Plot to Observing Cars Age vs Selling Price :**

# %%
fig = px.scatter(cars_24_data_frame, 
                 x=cars_24_data_frame['car_age'],
                 y=cars_24_data_frame['Price'], 
                 opacity=0.8, 
                 title='Cars Age vs. Selling Price')
fig.update_traces(marker_size=5)
fig.show()

# %% [markdown]
# **The graph shows:**
#
# **Negative correlation: As the age of the car increases (moving from left to right on the x-axis), the selling price generally decreases (moving down on the y-axis). This suggests that older cars tend to have lower selling prices.**
#
# **Scatter: The dots are not perfectly aligned, indicating that there is some variation in the relationship. Other factors besides age may also influence the selling price of a car.**
#
# **Outliers: There are a few dots that are far from the general trend, indicating that these cars may have unusual characteristics (e.g., very high mileage, rare features) that affect their selling price.**

# %% [markdown]
# ### **Using a Scatter Plot to Observing Cars Age vs Selling Price based on Transmission :**

# %%
fig = px.scatter(cars_24_data_frame, x=cars_24_data_frame['Price'], y=cars_24_data_frame['car_age'], color=cars_24_data_frame['Transmission'], marginal_y="violin",
           marginal_x="box", trendline="ols", template="simple_white")
fig.show()

# %% [markdown]
# **The graph shows:**
#
# **Negative correlation between age and price: As the age of the car increases, the selling price generally decreases, regardless of the transmission type.**
#
# **Difference in age distribution: The box plots show that manual transmission cars tend to be older than automatic transmission cars.**
#
# **Difference in price distribution: The violin plots show that automatic transmission cars generally have higher selling prices than manual transmission cars.**

# %% [markdown]
# ### **Using a Scatter Plot to Observing Cars Age vs Selling Price based on different Fuel Type :**

# %%
fig = px.scatter(cars_24_data_frame, x=cars_24_data_frame['Price'], y=cars_24_data_frame['car_age'], color=cars_24_data_frame['Fuel type'], marginal_y="violin",
           marginal_x="box", trendline="ols", template="simple_white")
fig.show()

# %% [markdown]
# **The graph shows:**
#
# **Negative correlation between age and price: As the age of the car increases, the selling price generally decreases, regardless of the fuel type.**
#
# **Differences in age distribution: The box plots show that there are some differences in the age distributions of cars with different fuel types.**
#
# **Differences in price distribution: The violin plots show that there are some differences in the price distributions of cars with different fuel types. For example, diesel cars tend to have higher selling prices than petrol cars, while CNG cars have the lowest selling prices on average.**

# %% [markdown]
# ## **Scatter matrix Visualization to explore the relationships between price, kilometers driven, and car age :**

# %%
import plotly.express as px
df = px.data.iris()
fig = px.scatter_matrix(cars_24_data_frame, dimensions=['Price','KM driven', 'car_age'])
fig.show()

# %% [markdown]
# **The scatter matrix reveals the following relationships between the three variables:**
#
# **Price and car age: There's a strong negative correlation, meaning that older cars generally have lower prices.**
#
# **Price and kilometers driven: There's a weak positive correlation, suggesting that cars with higher mileage might have slightly higher prices, but this relationship is not very strong.**
#
# **Kilometers driven and car age: There's a weak positive correlation, indicating that older cars tend to have higher mileage.**

# %% [markdown]
# ## **Creating a copy of the original DataFrame and then removing the specified Columns from the copy.**

# %%
cars_24_data_frame_updated=cars_24_data_frame.copy()
cars_24_data_frame_updated.drop(['Model Name','Spare key','Manufacturing_year'],axis=1,inplace=True)

# %%
cars_24_data_frame_updated
# Out:
#         Price  Engine capacity Transmission  KM driven  Ownership Fuel type  \
# 0      561000             1197       Manual      25847          2    Petrol
# 1      498000             1197       Manual      55511          2    Petrol
# 2      577000             1197       Manual      47110          1    Petrol
# 3     1084000             1462    Automatic      35378          1    Petrol
# 4      603000             1197       Manual      91856          1    Petrol
# ...       ...              ...          ...        ...        ...       ...
# 1440   862000             1462       Manual      19901          1    Petrol
# 1441   507000             1373       Manual      50022          1    Petrol
# 1442   554000             1197       Manual      58679          1    Petrol
# 1443   557000             1373       Manual      73948          2    Petrol
# 1444   256000              998       Manual      55994          1    Petrol
#
#       Imperfections  Repainted Parts  car_age
# ...

# %%
# Handle categorical variables
categorical_cols = [ 'Transmission', 'Fuel type']
data_cat = pd.get_dummies(cars_24_data_frame_updated, columns=categorical_cols).astype(int)

# %%
correlation_matrix=data_cat.corr()

# %% [markdown]
# ## **Creating a Correlation Matrix :**

# %%
# Create heatmap
plt.figure(figsize=(16, 12))
sns.heatmap(correlation_matrix, annot=True, cmap='magma', linewidths=0.97)
plt.title('Correlation Heatmap')
plt.show()

# %% [markdown]
# ## **Interpretation of the heatmap:**
#
# ### **Strong positive correlations:**
# Price and Engine capacity: Cars with higher engine capacities tend to have higher prices (0.72).
#
# KM driven and car age: Cars with higher mileage tend to be older (0.53).
#
# ### **Strong negative correlations:**
# Price and car age: Older cars tend to have lower prices (-0.62).
#
# Engine capacity and Fuel type CNG: Cars with CNG fuel tend to have lower engine capacities (-0.75).
#
# Fuel type CNG and Fuel type Petrol: CNG and petrol are mutually exclusive fuel types, so they have a strong negative correlation (-0.75).
#
# Fuel type Diesel and Fuel type Petrol: Diesel and petrol are mutually exclusive fuel types, so they have a strong negative correlation (-0.75).
#
# ### **Moderate positive correlations:**
# Price and Ownership: Cars with more owners might have slightly higher prices (0.19).
#
# KM driven and Imperfections: Cars with higher mileage might have more imperfections (0.27).
#
# Repainted Parts and car age: Older cars might have more repainted parts (0.26).
#
# ### **Moderate negative correlations:**
# Price and Imperfections: Cars with more imperfections might have slightly lower prices (-0.25).
#
# Engine capacity and KM driven: Cars with higher engine capacities might have slightly lower mileage (-0.31).
#
# ### **Weak correlations:**
# The remaining correlations between variables are relatively weak, indicating that there is little or no linear relationship between them.

# %% [markdown]
# # Importing All the Requird Libraries for Modelling

# %%
import pandas as pd
from sklearn.preprocessing import MinMaxScaler
from sklearn.pipeline import Pipeline
from sklearn.model_selection import train_test_split, GridSearchCV
from sklearn.preprocessing import StandardScaler
from sklearn.linear_model import Ridge, LinearRegression,Lasso
from sklearn.metrics import make_scorer, mean_squared_error, r2_score,mean_absolute_error,root_mean_squared_error

# %% [markdown]
# # Reading the Data from CSV

# %%
df = pd.read_csv(r"A:\DAIICT_sem1\Used_car_Price_prediction\Prediction\cars24data.csv")

# %%
df.head()
# Out:
#                             Model Name    Price  Manufacturing_year  \
# 0                2017 Maruti Swift VXI   561000                2017
# 1  2016 Maruti Baleno DELTA PETROL 1.2   498000                2016
# 2                2020 Maruti Swift VXI   577000                2020
# 3       2022 Maruti Ertiga VXI AT SHVS  1084000                2022
# 4                2019 Maruti Dzire VXI   603000                2019
#
#    Engine capacity Spare key Transmission  KM driven  Ownership Fuel type  \
# 0             1197        No       Manual      25847          2    Petrol
# 1             1197       Yes       Manual      55511          2    Petrol
# 2             1197        No       Manual      47110          1    Petrol
# 3             1462       Yes    Automatic      35378          1    Petrol
# 4             1197       Yes       Manual      91856          1    Petrol
#
#    Imperfections  Repainted Parts
# 0              6                2
# 1             12                1
# ...

# %% [markdown]
# # Cleaning the Model Name Feature

# %%
df["Model Name"].unique()
# Out:
# array(['2017 Maruti Swift VXI', '2016 Maruti Baleno DELTA PETROL 1.2',
#        '2020 Maruti Swift VXI', '2022 Maruti Ertiga VXI AT SHVS',
#        '2019 Maruti Dzire VXI', '2014 Maruti Alto 800 LXI',
#        '2018 Maruti Dzire VXI AMT', '2016 Maruti Swift Dzire VXI',
#        '2019 Maruti S PRESSO VXI', '2016 Maruti Swift ZXI',
#        '2023 Maruti Alto K10 VXI PLUS AMT', '2022 Maruti Alto LXI O',
#        '2019 Maruti Baleno DELTA PETROL 1.2',
#        '2014 Maruti Swift Dzire VXI', '2017 Maruti Swift VXI O',
#        '2021 Maruti Celerio ZXI PLUS AGS',
#        '2017 Maruti Dzire ZXI PLUS AMT', '2023 Maruti Celerio ZXI',
#        '2018 Maruti IGNIS ALPHA 1.2', '2021 Maruti S PRESSO VXI+',
#        '2018 Maruti Celerio VXI (O)', '2020 Maruti Alto VXI',
#        '2018 Maruti Baleno ZETA PETROL 1.2',
#        '2014 Maruti Wagon R Stingray VXI',
#        '2022 Maruti Ciaz DELTA 1.5 SHVS MT PETROL',
#        '2017 Maruti Celerio ZXI AMT', '2017 Maruti Celerio ZXI (O)',
# ...

# %% [markdown]
# **Applying Lambda Function after finding all the unique Model list**

# %%
df["Model Name"] = df["Model Name"].apply(lambda x : "Wagon R" if "Wagon R" in x else x)
df["Model Name"] = df["Model Name"].apply(lambda x : "Wagon R" if "Wagon-R" in x else x)

# %%
df["Model Name"] = df["Model Name"].apply(lambda x : "Ertiga" if "Ertiga" in x else x)

# %%
df["Model Name"] = df["Model Name"].apply(lambda x : "Dzire" if "Swift Dzire" in x else x)

# %%
df["Model Name"] = df["Model Name"].apply(lambda x : "Dzire" if "Dzire" in x else x)

# %%
df["Model Name"] = df["Model Name"].apply(lambda x : "Ciaz" if "Ciaz" in x else x)

# %%
df["Model Name"] = df["Model Name"].apply(lambda x : "Eeco" if "Eeco" in x else x)

# %%
df["Model Name"] = df["Model Name"].apply(lambda x : "Swift" if "Swift" in x else x)

# %%
df["Model Name"] = df["Model Name"].apply(lambda x : "Brezza" if "BREZZA" in x else x)

# %%
df["Model Name"] = df["Model Name"].apply(lambda x : "Brezza" if "Brezza" in x else x)

# %%
df["Model Name"] = df["Model Name"].apply(lambda x : "Alto" if "Alto" in x else x)

# %%
df["Model Name"] = df["Model Name"].apply(lambda x : "Ignis" if "IGNIS" in x else x)

# %%
df["Model Name"] = df["Model Name"].apply(lambda x : "S Presso" if "S PRESSO" in x else x)

# %%
df["Model Name"] = df["Model Name"].apply(lambda x : "XL6" if "XL6" in x else x)

# %%
df["Model Name"] = df["Model Name"].apply(lambda x : "Ritz" if "Ritz" in x else x)

# %%
df["Model Name"] = df["Model Name"].apply(lambda x : "Celerio" if "Celerio" in x else x)

# %%
df["Model Name"] = df["Model Name"].apply(lambda x : "Baleno" if "Baleno" in x else x)

# %%
df["Model Name"] = df["Model Name"].apply(lambda x : "Grand Vitara" if "Grand Vitara" in x else x) 
df["Model Name"] = df["Model Name"].apply(lambda x : "S Cross" if "S Cross" in x else x) 
df["Model Name"] = df["Model Name"].apply(lambda x : "Omni" if "Omni" in x else x) 
df["Model Name"] = df["Model Name"].apply(lambda x : "Omni" if "OMNI" in x else x) 
df["Model Name"] = df["Model Name"].apply(lambda x : "Omni" if "OMNI" in x else x) 
df["Model Name"] = df["Model Name"].apply(lambda x : "Zen Estilo" if "Zen Estilo" in x else x) 
df["Model Name"] = df["Model Name"].apply(lambda x : "A Star" if "A Star" in x else x)

# %%
df["Model Name"].value_counts()
# Out:
# Model Name
# Baleno          236
# Wagon R         235
# Alto            161
# Swift           151
# Celerio         141
# Ciaz            139
# Dzire           127
# S Presso         68
# Ignis            65
# Brezza           44
# Ertiga           32
# XL6              21
# Eeco              8
# Ritz              7
# S Cross           3
# Grand Vitara      2
# Omni              2
# A Star            2
# Zen Estilo        1
# Name: count, dtype: int64

# %% [markdown]
# # After Evaluating the outliers Removing them from data for better prediction

# %%
df=df[df['Price']<1050000]
df=df[df['Imperfections']<31]
df=df[df['Repainted Parts']<14]
df
# Out:
#      Model Name   Price  Manufacturing_year  Engine capacity Spare key  \
# 0         Swift  561000                2017             1197        No
# 1        Baleno  498000                2016             1197       Yes
# 2         Swift  577000                2020             1197        No
# 4         Dzire  603000                2019             1197       Yes
# 5          Alto  233000                2014              796        No
# ...         ...     ...                 ...              ...       ...
# 1440     Ertiga  862000                2021             1462        No
# 1441       Ciaz  507000                2015             1373        No
# 1442     Baleno  554000                2019             1197       Yes
# 1443       Ciaz  557000                2017             1373       Yes
# 1444    Wagon R  256000                2012              998        No
#
#      Transmission  KM driven  Ownership Fuel type  Imperfections  \
# ...

# %% [markdown]
# # One Hot Encoding to deal with the categorical Variable

# %%
categorical_cols = [ 'Transmission', 'Fuel type','Model Name','Manufacturing_year','Spare key']
data_cat = pd.get_dummies(df, columns=categorical_cols).astype(int)

# %%
data_cat
# Out:
#        Price  Engine capacity  KM driven  Ownership  Imperfections  \
# 0     561000             1197      25847          2              6
# 1     498000             1197      55511          2             12
# 2     577000             1197      47110          1              4
# 4     603000             1197      91856          1              3
# 5     233000              796      43780          1             10
# ...      ...              ...        ...        ...            ...
# 1440  862000             1462      19901          1              1
# 1441  507000             1373      50022          1              5
# 1442  554000             1197      58679          1             24
# 1443  557000             1373      73948          2              4
# 1444  256000              998      55994          1             20
#
#       Repainted Parts  Transmission_Automatic  Transmission_Manual  \
# 0                   2                       0                    1
# ...

# %% [markdown]
# # Listing all the column name after one hot encoding

# %%
list(data_cat.columns)
# Out:
# ['Price',
#  'Engine capacity',
#  'KM driven',
#  'Ownership',
#  'Imperfections',
#  'Repainted Parts',
#  'Transmission_Automatic',
#  'Transmission_Manual',
#  'Fuel type_CNG',
#  'Fuel type_Diesel',
#  'Fuel type_Petrol',
#  'Model Name_A Star',
#  'Model Name_Alto',
#  'Model Name_Baleno',
#  'Model Name_Brezza',
#  'Model Name_Celerio',
#  'Model Name_Ciaz',
#  'Model Name_Dzire',
#  'Model Name_Eeco',
#  'Model Name_Ertiga',
#  'Model Name_Ignis',
#  'Model Name_Omni',
#  'Model Name_Ritz',
#  'Model Name_S Cross',
#  'Model Name_S Presso',
#  'Model Name_Swift',
#  'Model Name_Wagon R',
#  'Model Name_XL6',
#  'Model Name_Zen Estilo',
#  'Manufacturing_year_2011',
#  'Manufacturing_year_2012',
#  'Manufacturing_year_2013',
#  'Manufacturing_year_2014',
#  'Manufacturing_year_2015',
#  'Manufacturing_year_2016',
#  'Manufacturing_year_2017',
#  'Manufacturing_year_2018',
#  'Manufacturing_year_2019',
#  'Manufacturing_year_2020',
#  'Manufacturing_year_2021',
# ...

# %% [markdown]
# # Dividing all the features into X and Y axis

# %%
features=[
 'Engine capacity',
 'KM driven',
 'Ownership',
 'Imperfections',
 'Repainted Parts',
 'Transmission_Automatic',
 'Transmission_Manual',
 'Fuel type_CNG',
 'Fuel type_Diesel',
 'Fuel type_Petrol',
 'Model Name_A Star',
 'Model Name_Alto',
 'Model Name_Baleno',
 'Model Name_Brezza',
 'Model Name_Celerio',
 'Model Name_Ciaz',
 'Model Name_Dzire',
 'Model Name_Eeco',
 'Model Name_Ertiga',
 'Model Name_Ignis',
 'Model Name_Omni',
 'Model Name_Ritz',
 'Model Name_S Cross',
 'Model Name_S Presso',
 'Model Name_Swift',
 'Model Name_Wagon R',
 'Model Name_XL6',
 'Model Name_Zen Estilo',
 'Manufacturing_year_2011',
 'Manufacturing_year_2012',
 'Manufacturing_year_2013',
 'Manufacturing_year_2014',
 'Manufacturing_year_2015',
 'Manufacturing_year_2016',
 'Manufacturing_year_2017',
 'Manufacturing_year_2018',
 'Manufacturing_year_2019',
 'Manufacturing_year_2020',
 'Manufacturing_year_2021',
 'Manufacturing_year_2022',
 'Manufacturing_year_2023',
 'Spare key_No',
 'Spare key_Yes']
X_all_features = data_cat[features]
y_feature_to_predict = data_cat['Price']

# %% [markdown]
# # Dividing the data set in Train Test Validation
# **80:10:10**

# %%
X_train, X_test, y_train, y_test = train_test_split(X_all_features, y_feature_to_predict, test_size=0.2, random_state=42)

# %%
X_test,X_val,y_test,y_val=train_test_split(X_test,y_test,test_size=0.5,random_state=42)

# %% [markdown]
# # Creating a Pipeline

# %%
pipelines = {
    'Ridge Regression': Pipeline([
        ('scaler', MinMaxScaler()),
        ('model', Ridge())
    ]),
     'Lasso Regression': Pipeline([
        ('scaler', StandardScaler()),  # Standardize the data
        ('model', Lasso(alpha=1.0, max_iter=10000,tol=1e-2))  # Lasso Regression model
    ]),  
     
    
    'Linear Regression': Pipeline([
        ('scaler', StandardScaler()),  # Standardize the data
        ('model', LinearRegression())  # Linear regression model
    ]),
    
        }

# %% [markdown]
# # Defining Parameter Grid

# %%
# Define hyperparameter grids for tuning inside my pipeline 
param_grids = {
    'Ridge Regression': {
    'model__alpha': [0.001, 0.01, 0.1, 1, 10, 100],  # Regularization strength
    'model__solver': ['auto', 'svd', 'cholesky'],  # Solvers for optimization
    'model__max_iter': [1000, 5000, 10000]  # Maximum number of iterations
                        },
    
    'Lasso Regression': {
    'model__alpha': [0.001, 0.01, 0.1, 1, 10, 100],  # Regularization strength
    'model__max_iter': [1000, 5000, 10000]
    },
}

# %% [markdown]
# # Defining Scoring Metrics

# %%
# Define evaluation metrics inside my pipeline 
scoring = {
    'MSE': make_scorer(mean_squared_error, greater_is_better=False),
    'R2': make_scorer(r2_score),
    'MAE': make_scorer(mean_absolute_error),
    'RMSE': make_scorer(root_mean_squared_error)    
}

# %% [markdown]
# # Fitting The Model and Evaluating  using GridSeachCV

# %%
# Iterate through models and evaluate performance using GridSearchCV
for name, pipeline in pipelines.items():
    print(f"\nTraining {name} MODEL...")
    

    # If hyperparameters exist for the model, use GridSearchCV
    if name in param_grids:
        grid_search = GridSearchCV(pipeline, param_grids[name], scoring=scoring, refit='R2', cv=5, return_train_score=True)
        grid_search.fit(X_train, y_train)
        best_model = grid_search.best_estimator_
        best_params = grid_search.best_params_
       
    else:
        pipeline.fit(X_train, y_train.to_numpy())
        best_model = pipeline
        best_params = "No hyperparameter tuning"
        
    
        # Evaluate on Training set
        y_train_pred = best_model.predict(X_train)  # Normalization is automatically applied to X_val
        
        train_mse = mean_squared_error(y_train, y_train_pred)
        val_r2 = r2_score(y_train, y_train_pred)
        val_mae = mean_absolute_error(y_train, y_train_pred)
        train_rmse=root_mean_squared_error(y_train, y_train_pred)
        print(f"\nEvaluating {name} on Train set ...\n\n")
        print(f"Best Parameters: {best_params}")
        print(f"Training set Mean Squared Error: {train_mse:.2f}")
        print(f"Training Mean Absolute Error: {val_mae:.2f}")
        print(f"Validation Root Mean Squared Error: {train_rmse:.2f}")
        print(f"Training set R² Score: {val_r2:.2f}")
        print(" \n")
        

        # Evaluate on validation set
        y_val_pred = best_model.predict(X_val)  # Normalization is automatically applied to X_val
        
        val_mse = mean_squared_error(y_val, y_val_pred)
        val_r2 = r2_score(y_val, y_val_pred)
        val_mae = mean_absolute_error(y_val, y_val_pred)
        val_rmse=root_mean_squared_error(y_val, y_val_pred)
        
        print(f"\nEvaluating {name} on Validation set ...\n\n")
        print(f"Best Parameters: {best_params}")
        print(f"Validation Mean Squared Error: {val_mse:.2f}")
        print(f"Validation Mean Absolute Error: {val_mae:.2f}")
        print(f"Validation Root Mean Squared Error: {val_rmse:.2f}")
        print(f"Validation R² Score: {val_r2:.2f}")
        print('\n')
        
        
        # Make predictions on the test set
        print(f"\nEvaluating {name} on Test Set...")
        y_test_pred = best_model.predict(X_test)
        
        #  Calculate evaluation metrics
        test_mse = mean_squared_error(y_test, y_test_pred)
        test_r2 = r2_score(y_test, y_test_pred)
        test_mae = mean_absolute_error(y_test, y_test_pred)
        test_rmse=root_mean_squared_error(y_test, y_test_pred)
        #  Print the evaluation metrics
        print(f"\n{name} Performance on Test Set:\n\n")
        print(f"Test Mean Squared Error: {test_mse:.2f}")
        print(f"Test Root Mean Squared Error: {test_rmse:.2f}")
        print(f"Test Mean Absolute Error: {test_mae:.2f}")
        print(f"Test R² Score: {test_r2:.2f}")
        print("\n")
# Out:
# Training Ridge Regression MODEL...
#
# Evaluating Ridge Regression on Train set ...
#
#
# Best Parameters: {'model__alpha': 0.1, 'model__max_iter': 1000, 'model__solver': 'svd'}
# Training set Mean Squared Error: 2836759247.70
# Training Mean Absolute Error: 41547.86
# Validation Root Mean Squared Error: 53261.24
# Training set R² Score: 0.90
#
#
#
# Evaluating Ridge Regression on Validation set ...
#
#
# Best Parameters: {'model__alpha': 0.1, 'model__max_iter': 1000, 'model__solver': 'svd'}
# Validation Mean Squared Error: 2242592515.39
# Validation Mean Absolute Error: 37166.35
# Validation Root Mean Squared Error: 47356.02
# Validation R² Score: 0.91
#
#
#
# Evaluating Ridge Regression on Test Set...
#
# Ridge Regression Performance on Test Set:
#
#
# Test Mean Squared Error: 2985888685.42
# Test Root Mean Squared Error: 54643.29
# Test Mean Absolute Error: 43557.65
# Test R² Score: 0.88
#
#
#
# Training Lasso Regression MODEL...
#
# Evaluating Lasso Regression on Train set ...
#
# ...
